# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv("./Hitters.csv")
df = df.dropna()
dms = pd.get_dummies(df[["League", "Division", "NewLeague"]])
y = df["Salary"]
x_ = df.drop(["Salary", "League", "Division", "NewLeague"], axis = 1).astype("float64")
x = pd.concat([x_, dms[["League_N", "Division_W", "NewLeague_N"]]], axis = 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 99)

# %%
from sklearn.svm import SVR
svr_model = SVR("linear").fit(x_train, y_train)
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/sklearn/utils/validation.py:72: FutureWarning: Pass kernel=linear as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %%
svr_model.intercept_
# Out:
# array([-36.27542968])

# %%
svr_model.coef_
# Out:
# array([[-0.19389262,  4.40958767, -6.13090614, -3.22129667, -0.57167793,
#          2.71158525,  9.09649321, -0.08269179, -0.45261361,  0.24254267,
#          1.73780821,  0.60081291, -0.35199287,  0.22222978, -0.09356406,
#         -3.85617062,  7.52455926,  0.05630015,  6.35388629]])

# %%
pred_y = svr_model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test, pred_y))
# Out:
# 429.1166883982825

# %%
svr_model = SVR("rbf").fit(x_train, y_train)
pred_y = svr_model.predict(x_test)
np.sqrt(mean_squared_error(y_test, pred_y))
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/sklearn/utils/validation.py:72: FutureWarning: Pass kernel=rbf as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# 635.6807650616796

# %%
svr_model = SVR("linear").fit(x_train, y_train)
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/sklearn/utils/validation.py:72: FutureWarning: Pass kernel=linear as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %%
svr_params = {"C": [0.1, 0.5, 1, 1.5, 2, 3]}
svr_cv_model = GridSearchCV(svr_model, svr_params, cv = 5).fit(x_train, y_train)

# %%
svr_cv_model.best_params_
# Out:
# {'C': 0.5}

# %%
svr_tuned = SVR("linear", C = 0.5).fit(x_train, y_train)
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/sklearn/utils/validation.py:72: FutureWarning: Pass kernel=linear as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %%
pred_y = svr_tuned.predict(x_test)

# %%
np.sqrt(mean_squared_error(y_test, pred_y))
# Out:
# 426.76088386138144
